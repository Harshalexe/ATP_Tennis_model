# %% [markdown]
# Data Analysis

# %% [markdown]
# Structural and random missing values
# siginficant, moderate and single missing values
# outlier detection and handling
# categorical encoding
# correaltion and multicorrelation

# %%
import pandas as pd
import numpy as np

# %%
from analysis_src.basic_data_inspection import DataInspectorMain, DataInspector, DatatypeInspector, summaryInspector
from analysis_src.missing_value import MissingValueAnalysis, SimpleMissingValueAnalysis
from analysis_src.univariate import UnivariateAnalysisMain, numericalAnalysis, categoricalAnalysis

# %% [markdown]
# 2008-2016 Data

# %%
data_path = "../data/2008-2016-deliveries(detailed).csv"
data_8_16=pd.read_csv(data_path)

# %%
data_inspector = DataInspectorMain(DatatypeInspector())
data_inspector.execute_inspection(data_8_16)
# Out:
# Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150460 entries, 0 to 150459
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          150460 non-null  int64
#  1   inning            150460 non-null  int64
#  2   batting_team      150460 non-null  object
#  3   bowling_team      150460 non-null  object
#  4   over              150460 non-null  int64
#  5   ball              150460 non-null  int64
#  6   batsman           150460 non-null  object
#  7   non_striker       150460 non-null  object
#  8   bowler            150460 non-null  object
#  9   is_super_over     150460 non-null  int64
#  10  wide_runs         150460 non-null  int64
#  11  bye_runs          150460 non-null  int64
#  12  legbye_runs       150460 non-null  int64
#  13  noball_runs       150460 non-null  int64
#  14  penalty_runs      150460 non-null  int64
#  15  batsman_runs      150460 non-null  int64
# ...

# %%
data_inspector.set_strategy(summaryInspector())
data_inspector.execute_inspection(data_8_16)
# Out:
# Summary Statistics: for numerical columns
#             match_id         inning           over           ball  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean      318.281317       1.482188      10.142649       3.616483
# std       182.955531       0.501768       5.674338       1.807698
# min         1.000000       1.000000       1.000000       1.000000
# 25%       161.000000       1.000000       5.000000       2.000000
# 50%       319.000000       1.000000      10.000000       4.000000
# 75%       476.000000       2.000000      15.000000       5.000000
# max       636.000000       4.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean        0.000538       0.037498       0.004885       0.022232
# std         0.023196       0.257398       0.114234       0.200104
# ...

# %%
missing= SimpleMissingValueAnalysis()
missing.analyze(data_8_16)
# Out:
# Identifying missing values...
# player_dismissed    143022
# dismissal_kind      143022
# fielder             145091
# dtype: int64

# %%
univariate = UnivariateAnalysisMain(numericalAnalysis())
univariate.execute_analysis(data_8_16, "total_runs")
# Out:
# Analyzing categorical variables...

# %%
univariate = UnivariateAnalysisMain(categoricalAnalysis())
univariate.execute_analysis(data_8_16, "batting_team")
# Out:
# Analyzing categorical variables...
# d:\Code\machine Learning & projects\ATP_tennis_model\analysis\analysis_src\univariate.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='muted')

# %% [markdown]
# 2008-2024 data deliveries

# %%
data_path = "../data/2008-2024-deliveries.csv"
data_8_24_d=pd.read_csv(data_path)

# %%
data_inspector = DataInspectorMain(DatatypeInspector())
data_inspector.execute_inspection(data_8_24_d)
# Out:
# Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
# ...

# %%
data_inspector.set_strategy(summaryInspector())
data_inspector.execute_inspection(data_8_24_d)
# Out:
# Summary Statistics: for numerical columns
#            match_id         inning           over           ball  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.197677       3.624486
# std    3.679913e+05       0.502643       5.683484       1.814920
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483340e+05       1.000000       4.000000       2.000000
# 50%    9.809670e+05       1.000000       9.000000       4.000000
# 75%    1.254066e+06       2.000000      14.000000       5.000000
# max    1.426312e+06       6.000000      19.000000      11.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.265001       0.067806       1.332807       0.049632
# std         1.639298       0.343265       1.626416       0.217184
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
missing= SimpleMissingValueAnalysis()
missing.analyze(data_8_24_d)
# Out:
# Identifying missing values...
# extras_type         246795
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %% [markdown]
# 2008-2024 matches

# %%
data_path = "../data/2008-2024-matches.csv"
data_8_24_m=pd.read_csv(data_path)

# %%
data_inspector = DataInspectorMain(DatatypeInspector())
data_inspector.execute_inspection(data_8_24_m)
# Out:
# Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
# ...

# %%
data_inspector.set_strategy(summaryInspector())
data_inspector.execute_inspection(data_8_24_m)
# Out:
# Summary Statistics: for numerical columns
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN
# Summary Statistics: for categorical columns
#           city        date           team1             team2     toss_winner  \
# ...

# %%
missing= SimpleMissingValueAnalysis()
missing.analyze(data_8_24_m)
# Out:
# Identifying missing values...
# city                 7
# winner               3
# player_of_match      3
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64
